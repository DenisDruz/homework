# %%
print('Привет! Меня зовут КиноБот. Для начала, давай познакомимся. Как тебя зовут?')

name = input()

print('Очень приятно,', name + '!')

print('Хочу немного поговорить с тобой про фильмы, ведь я КиноБот. Какой жанр фильмов тебе нравится больше: комедия, драма, экшн, фантастика, история? Только просьба: ответ напиши в точности одним из предложенных вариантов, с маленькой буквы и без точки в ответе. Чтобы я не сломался:)')

reply = input()

if reply == 'комедия':
  print('Прекрасно! Я тоже люблю от души посмеяться:)')
elif reply == 'драма':
  print('Иногда хочется поразмышлять о сложности и неоднозначности жизни, страданиях и переживаниях людей - я тебя понимаю...')
elif reply == 'экшн':
  print('Время от времени хочется отключить голову и впечатлиться новыми настоящими трюками Тома Круза или нарисованным на компьютере безумием семьи Доминика Торетто:)')
elif reply == 'фантастика':
  print('Пофантазировать о будущем и технологиях и том, насколько прекрасными или ужасными будущее и технологии будут, мы всегда любим!')
elif reply == 'история':
  print('История дает нам важные уроки для настоящего и будущего, поэтому окунуться в нее даже в художественном формате иногда очень полезно и увлекательно. Главное, чтобы сильно не переврали:) С другой стороны, это ведь лишь художественный фильм.')
else:
  print('Наверное, мы пока не до конца друг друга поняли в беседе о жанрах, или я пока слишком мало знаю о кино (что правда!), но я обещаю развиваться! Или ты общался со мной на каком-то из иностранных языков, которых я пока тоже не знаю. В любом случае, что-то пошло не так. Давай продолжим разговор о жанровых предпочтениях в следующий раз, а пока я хочу задать несколько вопросов по конкретным фильмам:)')

print('Если говорить про все жанры, из этих комедий какая тебе больше нравится: Один дома или Маска?:) (Пожалуйста, пиши названия фильмов в ответе на этот и последующие вопросы в предложенном виде, чтобы я смог тебя понять)')

reply1 = input()

if reply1 == 'Один дома':
  print('И я смеюсь над приключениями Кевина каждый Новый год!:)')
elif reply1 == 'Маска':
  print('Джим Керри в роли этого зеленоликого неуязвимого хулигана-весельчака бесподобен:) И Кэмерон Диас мы такой, конечно, тоже навсегда запомним, даром что дебют!')
else:
  print('Чувствую, я обязательно с этого ответа громко посмеюсь, когда хорошенько разберусь:) Но как-нибудь в другой раз, а пока продолжим.')

print('Какая драма вызвала более сильные переживания: Титаник или Реквием по мечте?')

reply2 = input()

if reply2 == 'Титаник':
  print('Понимаю:( Такая яркая, стремительная и очень трагичная история любви и история трагедии сотен семей:(')
elif reply2 == 'Реквием по мечте':
  print('Наркотики - это чудовищное зло! Мы этого никогда не забудем.')
else:
  print('Думаю, мне еще много над чем предстоит призадуматься или проплакать...')

print('Что сильнее впечатляет из экшенов: Форсаж или Миссия невыполнима?')

reply3 = input()

if reply3 == 'Форсаж':
  print('Что может быть важнее семьи, да?;) Только совершенно нереальный и абсурдный экшен, видимо:)')
elif reply3 == 'Миссия невыполнима':
  print('Честно: я не знаю, когда Том Круз перестанет сам выполнять все эти невероятные трюки:)')
else:
  print('Конечно, свет клином на этих двух адреналиновых франшизах не сошелся. Да и не всем боевички нравятся. Или я что-то еще не учёл, но пока пойдем дальше.')

print('Про фантастику - вопрос на засыпку: Матрица или Бегущий по лезвию 2049?')

reply4 = input()

if reply4 == 'Матрица':
  print('История об Избранном в мире победивших разумных машин - теперь с нами на все времена. Если речь, конечно, о первоначальной трилогии. С Матрицей 4 всё не так однозначно, хотя всё равно любопытно.')
elif reply4 == 'Бегущий по лезвию 2049':
  print('Дилемма репликантов, некоторые из которых были или стремились быть больше людьми, чем сами люди, - это несомненная классика, что в равной степени справедливо для обеих частей.')
else:
  print('C фантастикой бывает сложно, не спорю. Можем поговорить и о другом.')

print('Из исторического (в данном случае - историко-биографического) что вызывает больший интерес в 2023 году: Оппенгеймер или Наполеон?')

reply5 = input()

if reply5 == 'Оппенгеймер':
  print('По мне, очень впечатляющая история становления выдающегося учёного и серьёзная пища для размышлений в нынешние дни.')
elif reply5 == 'Наполеон':
  print('Говорят, много отступлений от исторической правды. Но и интересного много можно найти:) Ведь это художественный фильм про Бонапарта.')
else:
  print('Очень много интересного и достойного среди исторических фильмов. Это просто я пока мало знаю:)')

print('Позволь поинтересоваться: сколько тебе лет?')

age = int(input())

if age < 18:
  print('Подскажу: на некоторые фильмы и мультфильмы тебе может потребоваться сопровождение взрослых, а на фильмы 18+ сможешь сходить в кино, только когда самому исполниться 18.')
else:
  print('О-о-о, да Вы и сами взрослые, что я буду рассказывать:)')

print('Спасибо за приятное общение!:) До новых встреч!')
# Out:
# Привет! Меня зовут КиноБот. Для начала, давай познакомимся. Как тебя зовут?
# Денис
# Очень приятно, Денис!
# Хочу немного поговорить с тобой про фильмы, ведь я КиноБот. Какой жанр фильмов тебе нравится больше: комедия, драма, экшн, фантастика, история? Только просьба: ответ напиши в точности одним из предложенных вариантов, с маленькой буквы и без точки в ответе. Чтобы я не сломался:)
# фантастика
# Пофантазировать о будущем и технологиях и том, насколько прекрасными или ужасными будущее и технологии будут, мы всегда любим!
# Если говорить про все жанры, из этих комедий какая тебе больше нравится: Один дома или Маска?:) (Пожалуйста, пиши названия фильмов в ответе на этот и последующие вопросы в предложенном виде, чтобы я смог тебя понять)
# Маска
# Джим Керри в роли этого зеленоликого неуязвимого хулигана-весельчака бесподобен:) И Кэмерон Диас мы такой, конечно, тоже навсегда запомним, даром что дебют!
# Какая драма вызвала более сильные переживания: Титаник или Реквием по мечте?
# ...
